# %% [markdown]
# # APIs - Cumulative Lab
#
#
# ## Introduction
#
# We've seen how the Yelp API works and how to create basic visualizations using Folium. It's time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API.
#
# ## Objectives
#
# You will be able to:
#
# * Practice using functions to organize your code
# * Use pagination to retrieve all results from an API query
# * Practice parsing data returned from an API query
# * Practice interpreting visualizations of a dataset
# * Create maps using Folium

# %% [markdown]
# ## Your Task: Query Yelp for All Businesses in a Category and Analyze the Results
#
# ![restaurant counter with pizza](images/restaurant_counter.jpg)
#
# Photo by <a href="https://unsplash.com/@jordanmadrid?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Jordan Madrid</a> on <a href="/s/photos/pizza-restaurant?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Overview
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. In this lab, you will write a query of businesses on Yelp, then use *pagination* to retrieve all possible results for that query. Then you will create a summary of your findings, including a Folium map of the geographic locations of those businesses.
#
# ### Technical Details
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the **API limits**. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a **maximum of 50 results per request** and defaults to 20. Furthermore, any search will be limited to a **total of 1000 results**. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retrieving 50 at a time. Processes such as these are often referred to as pagination.
#
# Also, be mindful of the **API** ***rate*** **limits**. You can only make **5000 requests per day** and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use `time.sleep(n)` to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a list of dictionaries (for further exploration) and create a map using Folium to visualize the results geographically.
#
# ### Requirements
#
# #### 1. Make the Initial Request
#
# Start by filling in your API key to make the initial request to the business search API. Investigate the structure of the response you get back and start figuring out how you will extract the relevant information.
#
# #### 2. Add Pagination
#
# Using loops and functions, collect the maximum number of results for your query from the API.
#
# #### 3. Perform Exploratory Analysis
#
# Interpret visualizations related to the price range, average rating, and number of reviews for all query results.
#
# #### 4. Create a Folium Map
#
# Using latitude and longitude data, plot the query results on an interactive map.

# %% [markdown]
# ## 1. Make the Initial Request
#
# ### Querying
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you but make the request below.
#
# Use the `requests` library ([documentation here](https://requests.readthedocs.io/en/master/user/quickstart/#make-a-request)).
#
# You'll also need an API key from Yelp. If you haven't done this already, go to the Yelp [Manage App page](https://www.yelp.com/developers/v3/manage_app) and create a new app (after making an account if you haven't already).

# %%
# Replace None with appropriate code

# Import the requests library
import requests
import time
import folium

# Get this from the "Manage App" page. Make sure you set them
# back to None before pushing this to GitHub, since otherwise
# your credentials will be compromised
clientID = "f9pnHGp7FmBVsuU2r4z_ag"
key = "dBqEgEAY4wX2BOMk_S9MNIXQVHv4mxq0KDVEA3g5kfimhXVjJAEYOT2-5cnOXT8LB7evnJK7vcM2UkVAZHwBMZKXMGpBte3kGYJ5nodECyMwTNbnOwMtbgAw0FgSY3Yx"

# These can be whatever you want! But the solution uses "pizza"
# and "New York NY" if you want to compare your work directly
term = "pizza"
location = "New York NY"

# Set up params for request
url = "https://api.yelp.com/v3/businesses/search"
headers = {
    "Authorization": "Bearer {}".format(key)
}
url_params = {
    "term": term.replace(" ", "+"),
    "location": location.replace(" ", "+")
}

# Make the request using requests.get, passing in
# url, headers=headers, and params=url_params
response = requests.get(url=url, params=url_params, headers=headers)

# Confirm we got a 200 response
response
# Out:
# False

# %%
# Run this cell without changes

# Get the response body in JSON format
response_json = response.json()
# View the keys
response_json.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# ### Extracting Data
#
# Now, retrieve the value associated with the `'businesses'` key, and inspect its contents.

# %%
# Replace None with appropriate code

# Retrieve the value from response_json
businesses = response_json.get("businesses")

# View the first 2 records
businesses[:2]
# Out:
# [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HVjttLctuIzKL3LSlsRf-w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 4474,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 1961.8771417367063},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OCDZ4nXoaMHF0TraV0u2-g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 2512,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 308.56984360837544}]

# %% [markdown]
# ### Preparing Data
#
# Write a function `prepare_data` that takes in a list of dictionaries like `businesses` and returns a copy that has been prepared for analysis:
#
# 1. The `coordinates` key-value pair has been converted into two separate key-value pairs, `latitude` and `longitude`
# 2. All other key-value pairs except for `name`, `review_count`, `rating`, and `price` have been dropped
# 3. All dictionaries missing one of the relevant keys or containing null values have been dropped
#
# In other words, the final keys for each dictionary should be `name`, `review_count`, `rating`, `price`, `latitude`, and `longitude`.
#
# Complete the function in the cell below:

# %%
# Replace None with appropriate code

def prepare_data(data_list):
    """
    This function takes in a list of dictionaries and prepares it
    for analysis
    """
    
    # Make a new list to hold results
    results = []
    
    for b_data in data_list:
    
        # Make a new dictionary to hold prepared data for this business
        prepared_data = {}
        
        # .get() returns none id the key DNE
        prepared_data["name"] = b_data.get("name")
        prepared_data["review_count"] = b_data.get("review_count")
        prepared_data["rating"] = b_data.get("rating")
        prepared_data["price"] = b_data.get("price")
        prepared_data["latitude"] = b_data.get("coordinates").get("latitude")
        prepared_data["longitude"] = b_data.get("coordinates").get("longitude")
        
        # Add to list if all values are present
        if all(prepared_data.values()):
            results.append(prepared_data)
    
    return results
    
# Test out function
prepared_businesses = prepare_data(businesses)
prepared_businesses[:5]
# Out:
# [{'name': 'Prince Street Pizza',
#   'review_count': 4474,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575},
#  {'name': "Juliana's",
#   'review_count': 2512,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': "Lombardi's Pizza",
#   'review_count': 6386,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 754,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': 'Rubirosa',
#   'review_count': 2752,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.722766,
#   'longitude': -73.996233}]

# %% [markdown]
# Check that your function created the correct keys:

# %%
# Run this cell without changes

assert sorted(list(prepared_businesses[0].keys())) == ['latitude', 'longitude', 'name', 'price', 'rating', 'review_count']

# %% [markdown]
# The following code will differ depending on your query, but we expect there to be 20 businesses in the original list, and potentially fewer in the prepared list (if any of them were missing data):

# %%
# Run this cell without changes
print("Original:", len(businesses))
print("Prepared:", len(prepared_businesses))
# Out:
# Original: 20
# Prepared: 18

# %% [markdown]
# Great! We will reuse this function once we have retrieved the full dataset.

# %% [markdown]
# ## 2. Add Pagination
#
# Now that you are able to extract information from one page of the response, let's figure out how to request as many pages as possible.
#
# ### Determining the Total
#
# Depending on the number of total results for your query, you will either retrieve all of the results, or just the first 1000 (if there are more than 1000 total).
#
# We can find the total number of results using the `"total"` key:

# %%
# Run this cell without changes
response_json["total"]
# Out:
# 11800

# %% [markdown]
# (This is specific to the implementation of the Yelp API. Some APIs will just tell you that there are more pages, or will tell you the number of pages total, rather than the total number of results. If you're not sure, always check the documentation.)
#
# In the cell below, assign the variable `total` to either the value shown above (if it is less than 1000), or 1000.

# %%
# Replace None with appropriate code
total = None

# %% [markdown]
# ### Calculating the Offsets
#
# The documentation states in the parameters section:
#
# > **Name**: `limit`, **Type:** int, **Description:** Optional. Number of business results to return. By default, it will return 20. Maximum is 50.
#
# > **Name**: `offset`, **Type:** int, **Description:** Optional. Offset the list of returned business results by this amount.
#
# So, to get the most results with the fewest API calls we want to set a limit of 50 every time. If, say, we wanted to get 210 total results, that would mean:
#
# 1. Offset of `0` (first 50 records)
# 2. Offset of `50` (second 50 records)
# 3. Offset of `100` (third 50 records)
# 4. Offset of `150` (fourth 50 records)
# 5. Offset of `200` (final 10 records)
#
# In the cell below, create a function `get_offsets` that takes in a total and returns a list of offsets for that total. You can assume that there is a limit of 50 every time.
#
# *Hint: you can use `range` ([documentation here](https://docs.python.org/3.3/library/stdtypes.html?highlight=range#range)) to do this in one line of code. Just make the returned result is a list.*

# %%
# Replace None with appropriate code
def get_offsets(total):
    """
    Get a list of offsets needed to get all pages
    of data up until the total
    """
    None

# %% [markdown]
# Check that your function works below:

# %%
# Run this cell without changes

assert get_offsets(200) == [0, 50, 100, 150]
assert get_offsets(210) == [0, 50, 100, 150, 200]

# %% [markdown]
# ### Putting It All Together
#
# Recall that the following variable has already been declared for you:

# %%
# Run this cell without changes
url_params

# %% [markdown]
# We'll go ahead and also specify that the limit should be 50 every time:

# %%
# Run this cell without changes
url_params["limit"] = 50

# %% [markdown]
# In order to modify the offset, you'll need to add it to `url_params` with the key `"offset"` and whatever value is needed.
#
# In the cell below, write code that:
#
# * Creates an empty list for the full prepared dataset
# * Loops over all of the offsets from `get_offsets` and makes an API call each time with the specified offset
# * Calls `prepare_data` to get a cleaned version of the result of each API call
# * Extends the full prepared dataset list with each query's prepared dataset

# %%
# Replace None with appropriate code

# Create an empty list for the full prepared dataset
full_dataset = []

term = "pizza"
location = "New York NY"
limit = 50
TOTAL = 1000

url = "https://api.yelp.com/v3/businesses/search"
headers = {"Authorization": "Bearer {}".format(key)}

for offset_num in range(int(TOTAL/limit)):
    
    url_params = {
        "term": term.replace(" ", "+"),
        "location": location.replace(" ", "+"),
        "limit" : limit,
        "offset": offset_num * limit
    }

    response = requests.get(url=url, params=url_params, headers=headers)
    
    if response.status_code != 200:
        time.sleep(1)
        response = requests.get(url=url, params=url_params, headers=headers)
    
    full_dataset.extend(prepare_data(response.json()["businesses"]))
    
    print(round((limit*offset_num)/TOTAL, 2), end="\r")

# Check the length of the full dataset. It will be up to `total`,
# potentially less if there were missing values
len(full_dataset)
# Out:
# 0.95
# 788

# %%
full_dataset
# Out:
# [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HVjttLctuIzKL3LSlsRf-w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 4474,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 1961.8771417367063},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OCDZ4nXoaMHF0TraV0u2-g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 2512,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 308.56984360837544},
#  {'id': 'v1DHGRNCH9247WLYoaoA9A',
#   'alias': 'l-industrie-pizzeria-brooklyn',
#   'name': "L'industrie Pizzeria",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Llq71WxE8MzpOodJoa6-kg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 754,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '254 S 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#   'phone': '+17185990002',
#   'display_phone': '(718) 599-0002',
#   'distance': 3145.016041338447},
#  {'id': 'WG639VkTjmK5dzydd1BBJA',
#   'alias': 'rubirosa-new-york-2',
#   'name': 'Rubirosa',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 2752,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '235 Mulberry St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#   'phone': '+12129650500',
#   'display_phone': '(212) 965-0500',
#   'distance': 1932.9467701334759},
#  {'id': 'Q9F2ocrmYuGt1yn3M7MOBw',
#   'alias': 'lucali-brooklyn-3',
#   'name': 'Lucali',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Yl_eZ_DW_iaumnU-pfSoaw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lucali-brooklyn-3?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 1847,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.681840746711224, 'longitude': -74.0003327},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '575 Henry St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['575 Henry St', 'Brooklyn, NY 11231']},
#   'phone': '+17188584086',
#   'display_phone': '(718) 858-4086',
#   'distance': 2673.589406211555},
#  {'id': 'FhXjAc6nKLf414KxYujUHw',
#   'alias': 'robertas-brooklyn-2',
#   'name': "Roberta's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8fY9fA5TtCF0ebdTNph9mQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 3159,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70493, 'longitude': -73.93399},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '261 Moore St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#   'phone': '+17184171118',
#   'display_phone': '(718) 417-1118',
#   'distance': 5083.5233118395545},
#  {'id': 'uc5qQMzs96rzjK27epDCug',
#   'alias': 'joes-pizza-new-york-4',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1TvTRG9HFmEGaTSBMcUBhA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 2861,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73060076, 'longitude': -74.00215997},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '7 Carmine St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7 Carmine St', 'New York, NY 10014']},
#   'phone': '+12123661182',
#   'display_phone': '(212) 366-1182',
#   'distance': 2874.702513677348},
#  {'id': 'RfFXF-Momn0tLIgh1TZKLw',
#   'alias': 'di-fara-pizza-new-york-2',
#   'name': 'Di Fara Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SaWdpz9ZL003jQBI1LZooQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/di-fara-pizza-new-york-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 14,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.706894091267536,
#    'longitude': -74.00184964894031},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '108 South St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['108 South St', 'New York, NY 10038']},
#   'phone': '+19173883130',
#   'display_phone': '(917) 388-3130',
#   'distance': 657.021625043188},
#  {'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#   'alias': 'johns-of-bleecker-street-new-york-2',
#   'name': "John's of Bleecker Street",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r2bmU0uH-6SSxqjRbITDgg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 2354,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '278 Bleecker St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#   'phone': '+12122431680',
#   'display_phone': '(212) 243-1680',
#   'distance': 3010.899021476809},
#  {'id': 'oJ_XSPZFpvIt6rvheSQl7A',
#   'alias': 'bleecker-street-pizza-new-york',
#   'name': 'Bleecker Street Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KdA2kfYYI9-JFb_Qmdb74A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 2679,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7320627016512,
#    'longitude': -74.0036552270137},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '69 7th Ave S',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['69 7th Ave S', 'New York, NY 10014']},
#   'phone': '+12129244466',
#   'display_phone': '(212) 924-4466',
#   'distance': 3073.5742196084057},
#  {'id': '2ggi1luerd3Mf_C82JvCYg',
#   'alias': 'grimaldis-pizzeria-brooklyn-4',
#   'name': "Grimaldi's Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TNKqW31PTvtSw6-Lbc1mtA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 4846,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.7026459, 'longitude': -73.9932413},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#   'phone': '+17188584300',
#   'display_phone': '(718) 858-4300',
#   'distance': 323.61541267581333},
#  {'id': '0UdC0VYX6aAvLiOcpR4MVQ',
#   'alias': 'joes-pizza-new-york-7',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BTCcvlqxlp2MOeK_rHa8lQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-7?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 1007,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73331, 'longitude': -73.98763},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '150 E 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['150 E 14th St', 'New York, NY 10003']},
#   'phone': '+12123889474',
#   'display_phone': '(212) 388-9474',
#   'distance': 3140.2631090277323},
#  {'id': '2xQmBB6w-W6lxiex80fA9A',
#   'alias': 'luigis-pizzeria-brooklyn-4',
#   'name': "Luigi's Pizzeria",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/j8wXRUzFnc8XJCFqpt5ZsQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/luigis-pizzeria-brooklyn-4?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 275,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6897, 'longitude': -73.965369},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '326 Dekalb Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['326 Dekalb Ave', 'Brooklyn, NY 11205']},
#   'phone': '+17187832430',
#   'display_phone': '(718) 783-2430',
#   'distance': 3001.8318150390764},
#  {'id': 'hGksyTiHBBdrhbiVjXzWVw',
#   'alias': 'scarrs-pizza-new-york',
#   'name': "Scarr's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xonxGJK91P_Ow3iY7olsxA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/scarrs-pizza-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 605,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71534, 'longitude': -73.9914},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '22 Orchard St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['22 Orchard St', 'New York, NY 10002']},
#   'phone': '+12123343481',
#   'display_phone': '(212) 334-3481',
#   'distance': 1125.7843300426755},
#  {'id': '4MIHutYjIwoXsi-R8TlrSg',
#   'alias': 'belluccis-pizzeria-astoria-2',
#   'name': "Bellucci's Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Wg3vw-TFbEHm5dYkaXX1Tg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/belluccis-pizzeria-astoria-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 69,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.76432, 'longitude': -73.91649},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '37-08 30th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Astoria',
#    'zip_code': '11103',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['37-08 30th Ave', 'Astoria, NY 11103']},
#   'phone': '+17184072497',
#   'display_phone': '(718) 407-2497',
#   'distance': 9270.489897001944},
#  {'id': 'C8j0q4Ma_S5hBGuAI-aaww',
#   'alias': 'di-fara-pizza-brooklyn',
#   'name': 'Di Fara Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Et320ndrVyYACtZkdzb-Bw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/di-fara-pizza-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 3829,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.625093, 'longitude': -73.961531},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1424 Ave J',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11230',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1424 Ave J', 'Brooklyn, NY 11230']},
#   'phone': '+17182581367',
#   'display_phone': '(718) 258-1367',
#   'distance': 9352.269072867253},
#  {'id': 'QfCbV1_VIjfCkowro_WGNA',
#   'alias': 'luigis-pizza-brooklyn',
#   'name': "Luigi's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/baEpvTY5HnpxwrOx5vk_zg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/luigis-pizza-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 418,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.66163, 'longitude': -73.99334},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '686 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['686 5th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+17184993857',
#   'display_phone': '(718) 499-3857',
#   'distance': 4871.041578229889},
#  {'id': 'i_rg-OLXQbpRUN7O3MeCeA',
#   'alias': 'piz-zetta-brooklyn-2',
#   'name': 'Piz-zetta',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9L4viDwAGx3obgYLnXMA6g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/piz-zetta-brooklyn-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 317,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.69116658201196,
#    'longitude': -73.99065911521895},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '90 Livingston St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['90 Livingston St', 'Brooklyn, NY 11201']},
#   'phone': '+17184227878',
#   'display_phone': '(718) 422-7878',
#   'distance': 1616.95941062503},
#  {'id': 'oOr6Ta5gZyDl6PyZ1cq7pg',
#   'alias': 'east-village-pizza-new-york',
#   'name': 'East Village Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JiV117pdeH3hG6J91KfPeA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/east-village-pizza-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 435,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.728199, 'longitude': -73.985182},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '145 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['145 1st Ave', 'New York, NY 10003']},
#   'phone': '+12125294545',
#   'display_phone': '(212) 529-4545',
#   'distance': 2643.8575043591286},
#  {'id': '-CCfu19Uuy_kD2t4ZwsQfA',
#   'alias': 'village-square-pizza-new-york-3',
#   'name': 'Village Square Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rc1se5XkYcc6ABo8g7u4Zw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/village-square-pizza-new-york-3?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 238,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72748, 'longitude': -73.98268},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '147 Ave A',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['147 Ave A', 'New York, NY 10009']},
#   'phone': '+19176757709',
#   'display_phone': '(917) 675-7709',
#   'distance': 2640.263835248777},
#  {'id': 'GRXvvB1OKMuW4XDWEaVAlg',
#   'alias': 'joes-pizza-brooklyn-8',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7RQebflR3JvTcMWRbVC86g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-brooklyn-8?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 413,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7168952, 'longitude': -73.95892996733771},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '216 Bedford Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['216 Bedford Ave', 'Brooklyn, NY 11249']},
#   'phone': '+17183882216',
#   'display_phone': '(718) 388-2216',
#   'distance': 3241.190355020982},
#  {'id': '16ZnHpuaaBt92XWeJHCC5A',
#   'alias': 'olio-e-più-new-york-7',
#   'name': 'Olio e Più',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/l4peUZMi7CLFcG3w3jnYvQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/olio-e-pi%C3%B9-new-york-7?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 3511,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.733798036104304,
#    'longitude': -73.99977392649927},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3 Greenwich Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3 Greenwich Ave', 'New York, NY 10014']},
#   'phone': '+12122436546',
#   'display_phone': '(212) 243-6546',
#   'distance': 3186.3804982206075},
#  {'id': 'pGr5QuQU7Ur5GHLvXbT8bw',
#   'alias': 'paulie-gees-brooklyn',
#   'name': "Paulie Gee's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1j39J4NABK_RBtO-l90QNg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paulie-gees-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 1320,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.729546, 'longitude': -73.958568},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '60 Greenpoint Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['60 Greenpoint Ave', 'Brooklyn, NY 11222']},
#   'phone': '+13479873747',
#   'display_phone': '(347) 987-3747',
#   'distance': 4027.308250680752},
#  {'id': 'qoBcWhGwlcUsKIQ2nB22vA',
#   'alias': 'lombardos-of-bay-ridge-brooklyn-2',
#   'name': "Lombardo's of Bay Ridge",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dApR-oBFGa2kQIpmEeasfA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lombardos-of-bay-ridge-brooklyn-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 181,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.634741, 'longitude': -74.0284259},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '279 71st St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['279 71st St', 'Brooklyn, NY 11209']},
#   'phone': '+17182387100',
#   'display_phone': '(718) 238-7100',
#   'distance': 8367.095256061873},
#  {'id': 'affWh2WFSMayL04l9lr47g',
#   'alias': 'roberta-s-brooklyn',
#   'name': 'Roberta’s',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rdK-sou4FgwoUAy1FFRBCw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/roberta-s-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 9,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71613781459604,
#    'longitude': -73.9665876020738},
#   'transactions': [],
#   'location': {'address1': '6 Grand St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6 Grand St', 'Brooklyn, NY 11249']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2620.492305749973},
#  {'id': 'TWH4MjLtN1fKlF-7n6YXHg',
#   'alias': 'lil-frankies-new-york',
#   'name': "Lil Frankie's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/t0OsEVlzDWgM_NMGVHmPiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lil-frankies-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 1361,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.723625, 'longitude': -73.988555},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '19 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 1st Ave', 'New York, NY 10003']},
#   'phone': '+12124204900',
#   'display_phone': '(212) 420-4900',
#   'distance': 2079.0350425992006},
#  {'id': '2FgUndzCT_jJATbmrBDVBg',
#   'alias': 'paulie-gees-slice-shop-brooklyn',
#   'name': "Paulie Gee's Slice Shop",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/So5FTaF3_Sf0fWYLhQ-Ofw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paulie-gees-slice-shop-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 287,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72836, 'longitude': -73.9572},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '110 Franklin St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['110 Franklin St', 'Brooklyn, NY 11222']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 4034.987858819694},
#  {'id': 'g8Ai7LiusDgN_fpsdD8_fQ',
#   'alias': 'joe-and-sals-pizza-of-fort-greene-brooklyn',
#   'name': "Joe & Sal's Pizza Of Fort Greene",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ckWXIuVr3iw8HyTkSsWDzA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joe-and-sals-pizza-of-fort-greene-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 27,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.69335, 'longitude': -73.97214},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '353 Myrtle Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['353 Myrtle Ave', 'Brooklyn, NY 11205']},
#   'phone': '+19179091420',
#   'display_phone': '(917) 909-1420',
#   'distance': 2299.366488836825},
#  {'id': '-9NO2IDCJMyNGZMAQ1-VQw',
#   'alias': 'ny-pizza-suprema-new-york',
#   'name': 'NY Pizza Suprema',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EqbDXneMuQP6pw6GemVdQA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ny-pizza-suprema-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 2313,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7502059936523,
#    'longitude': -73.9953231811523},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '413 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['413 8th Ave', 'New York, NY 10001']},
#   'phone': '+12125948939',
#   'display_phone': '(212) 594-8939',
#   'distance': 4977.847939164096},
#  {'id': 'xrgzB0pvsxeGEIboE6I2gg',
#   'alias': 'patsys-pizzeria-brooklyn-2',
#   'name': "Patsy's Pizzeria",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/naIBxTISC8Uk7LxT6JwMZw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/patsys-pizzeria-brooklyn-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 597,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6818695, 'longitude': -73.976181},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '450 Dean St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11217',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['450 Dean St', 'Brooklyn, NY 11217']},
#   'phone': '+17186222268',
#   'display_phone': '(718) 622-2268',
#   'distance': 3034.9893998767334},
#  {'id': 'S4uozcDEieoaXxIJ6TsUoQ',
#   'alias': 'dellaroccos-brooklyn-3',
#   'name': "Dellarocco's Brick Oven Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RGsip2vQXryVUbOrXfYBkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dellaroccos-brooklyn-3?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 325,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6950309, 'longitude': -73.9961252},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '214 Hicks St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['214 Hicks St', 'Brooklyn, NY 11201']},
#   'phone': '+17188581010',
#   'display_phone': '(718) 858-1010',
#   'distance': 1170.2700329972115},
#  {'id': '9Qcxauog2gOTKt-L4Ljxxw',
#   'alias': 'burrata-pizza-new-york',
#   'name': 'Burrata Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/41VcPOjAc0FojmtKJBIwWA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/burrata-pizza-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 19,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7302, 'longitude': -73.98069},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '221 Ave A',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['221 Ave A', 'New York, NY 10009']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2981.056338871247},
#  {'id': 'k3vbv0tbV83IrfaH2Z5t5Q',
#   'alias': 'maneros-pizza-new-york',
#   'name': "Manero's Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jHiIWR6M-PnbWp-rcQeiWQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/maneros-pizza-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 78,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.717593, 'longitude': -73.998396},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '113 Mulberry St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['113 Mulberry St', 'New York, NY 10013']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1398.553837392163},
#  {'id': '6ECcDYsRgmfv0eKXk-c11Q',
#   'alias': 'la-nonna-krispy-krust-pizza-brooklyn',
#   'name': 'La Nonna Krispy Krust Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/snKP9CUQHOth_2vox3Z79g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-nonna-krispy-krust-pizza-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 67,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.717953, 'longitude': -73.9637027},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '175 Kent Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['175 Kent Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13473842100',
#   'display_phone': '(347) 384-2100',
#   'distance': 2929.5564145017947},
#  {'id': '15k7iqFbhf4h8L01yggLqg',
#   'alias': 'song-e-napule-new-york',
#   'name': 'Song E Napule',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y9G-nheTrxSrx4Cqg0HzHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/song-e-napule-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 629,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72813, 'longitude': -74.00188},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '146 W Houston St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['146 W Houston St', 'New York, NY 10012']},
#   'phone': '+12125331242',
#   'display_phone': '(212) 533-1242',
#   'distance': 2607.168270554507},
#  {'id': 'Aazjxg21VH2cncWYBAv68Q',
#   'alias': 'sottocasa-pizzeria-brooklyn-3',
#   'name': 'Sottocasa Pizzeria',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MbBAMb3kb1VXtF9M5ptazA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sottocasa-pizzeria-brooklyn-3?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 684,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.688285, 'longitude': -73.989006},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '298 Atlantic Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['298 Atlantic Ave', 'Brooklyn, NY 11201']},
#   'phone': '+17188528758',
#   'display_phone': '(718) 852-8758',
#   'distance': 1955.3105885559205},
#  {'id': 'xxgcU_oFIox_pAmroo9WwA',
#   'alias': 'front-street-pizza-brooklyn',
#   'name': 'Front Street Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ybrfmg0lGdBoJRM7X1_s3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/front-street-pizza-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 422,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70244, 'longitude': -73.98943},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '80 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['80 Front St', 'Brooklyn, NY 11201']},
#   'phone': '+17188753700',
#   'display_phone': '(718) 875-3700',
#   'distance': 550.4392264831844},
#  {'id': 'hFmz7HH2og9hn7xNNv20yw',
#   'alias': 'il-porto-ristorante-brooklyn',
#   'name': 'Il Porto Ristorante & Wood Fired Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ka4_bkUB_I5JAZyRjAnbLQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/il-porto-ristorante-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 366,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6974427, 'longitude': -73.9675197},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '37 Washington Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['37 Washington Ave', 'Brooklyn, NY 11205']},
#   'phone': '+17186240954',
#   'display_phone': '(718) 624-0954',
#   'distance': 2433.138320005117},
#  {'id': 'r1PWMTbFXBmEhi0scGPf3w',
#   'alias': 'aces-pizza-brooklyn',
#   'name': "Ace's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DE09AfTdJ6vk5l9cqV8jAA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aces-pizza-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 103,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71505, 'longitude': -73.958365},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '637 Driggs Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['637 Driggs Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13477254366',
#   'display_phone': '(347) 725-4366',
#   'distance': 3210.927271587945},
#  {'id': 'AoezuAP-QOH6JZZOmyzJLg',
#   'alias': 'marinara-pizza-new-york-11',
#   'name': 'Marinara Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3pb0XoJkF5Zx6ZPwjfpdfw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/marinara-pizza-new-york-11?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 310,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7826, 'longitude': -73.95351},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1376 Lexington Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10128',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1376 Lexington Ave', 'New York, NY 10128']},
#   'phone': '+16465595100',
#   'display_phone': '(646) 559-5100',
#   'distance': 9234.660101173442},
#  {'id': 'H8qcX7MNNnC1bqE0LnIhKg',
#   'alias': 'simò-pizza-new-york-4',
#   'name': 'SIMÒ PIZZA',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qaSQsBdO9e1gz5OH9ROckw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sim%C3%B2-pizza-new-york-4?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 224,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7392597584612,
#    'longitude': -74.0088130692187},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '90-92 Gansevoort St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['90-92 Gansevoort St', 'New York, NY 10014']},
#   'phone': '+12124622703',
#   'display_phone': '(212) 462-2703',
#   'distance': 3954.1313238707344},
#  {'id': 'vpkTNjq9dRh9rT3Nh0pe-A',
#   'alias': 'nolita-pizza-new-york-2',
#   'name': 'Nolita Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iY3qXRWquMC433WvPZdMmw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nolita-pizza-new-york-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 153,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7208883, 'longitude': -73.9962404},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '68 Kenmare St',
#    'address2': None,
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['68 Kenmare St', 'New York, NY 10012']},
#   'phone': '+16468959131',
#   'display_phone': '(646) 895-9131',
#   'distance': 1725.0543086810944},
#  {'id': 'vVVmHacu2YAxKfpIjhfd1g',
#   'alias': 'norma-new-york-5',
#   'name': 'Norma',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qJKt5l2xSBUKOFRA6UOqVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/norma-new-york-5?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 549,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.743553, 'longitude': -73.980026},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '438 3rd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['438 3rd Ave', 'New York, NY 10016']},
#   'phone': '+12128890600',
#   'display_phone': '(212) 889-0600',
#   'distance': 4409.483534452521},
#  {'id': 'xeC9vn3dxVVzAMR_aFwfXg',
#   'alias': 'il-brigante-new-york',
#   'name': 'IL Brigante',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KJMXZEwKqswc0iVM_6sN7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/il-brigante-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 466,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.707492, 'longitude': -74.002571},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '214 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['214 Front St', 'New York, NY 10038']},
#   'phone': '+12122850222',
#   'display_phone': '(212) 285-0222',
#   'distance': 738.248263617683},
#  {'id': 'MwcRbM6lS6_8N67LmyBELA',
#   'alias': '99-cent-fresh-pizza-new-york-5',
#   'name': '99 Cent Fresh Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yy7ZIhBQiVIsoBINay-MIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/99-cent-fresh-pizza-new-york-5?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 630,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.76458, 'longitude': -73.98247},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1723 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1723 Broadway', 'New York, NY 10019']},
#   'phone': '+12122452155',
#   'display_phone': '(212) 245-2155',
#   'distance': 6652.683137648691},
#  {'id': 'ApZ_j43jjSZQe2AMDdO46w',
#   'alias': 'grand-street-pizza-new-york',
#   'name': 'Grand Street Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ypw5OQaw2nOE7p3_FDvT9g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grand-street-pizza-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 17,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7164, 'longitude': -73.98767},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '384 Grand St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['384 Grand St', 'New York, NY 10002']},
#   'phone': '+16469186194',
#   'display_phone': '(646) 918-6194',
#   'distance': 1350.7240473548673},
#  {'id': 'ON7ihGoWgZaBFDaLCYpk2Q',
#   'alias': 'rome-to-brooklyn-pizza-brooklyn-2',
#   'name': 'Rome To Brooklyn Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rGm_g8V5xl8DB5zOsHKHYA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rome-to-brooklyn-pizza-brooklyn-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 123,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.711886016839244, 'longitude': -73.9429006},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '755 Grand St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['755 Grand St', 'Brooklyn, NY 11211']},
#   'phone': '+17182693239',
#   'display_phone': '(718) 269-3239',
#   'distance': 4390.674583309917},
#  {'id': 'AHDlsNh8fODK9miC3zv3Zg',
#   'alias': 'unregular-pizza-new-york-2',
#   'name': 'Unregular Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FiM-keMJYaZyUSKrbUE7hA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/unregular-pizza-new-york-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 129,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.73398, 'longitude': -73.98961},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '135 4th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['135 4th Ave', 'New York, NY 10003']},
#   'phone': '+16466094699',
#   'display_phone': '(646) 609-4699',
#   'distance': 3163.0182107738174},
#  {'id': '3VJwpmmeoPlCN3J5p5miEQ',
#   'alias': 'brooklyns-homeslice-pizzeria-brooklyn',
#   'name': "Brooklyn's Homeslice Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PFbKEyhlyJIuGZxhqSYlKw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brooklyns-homeslice-pizzeria-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 181,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.680702, 'longitude': -73.967455},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '567 Vanderbilt Ave',
#    'address2': '',
# ...
#   'alias': 'mercato-new-york',
#   'name': 'Mercato',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LTDeQgRvclFWi5cfXOr3qg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mercato-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 1001,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.75619, 'longitude': -73.9937},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '352 W 39th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['352 W 39th St', 'New York, NY 10018']},
#   'phone': '+12126432000',
#   'display_phone': '(212) 643-2000',
#   'distance': 5644.746419510025},
#  {'id': 'J5y7oRfiGtxFDkYGKxFZkw',
#   'alias': 'anella-brooklyn',
#   'name': 'Anella',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EPFNvVV8wRrD2dyBxlFVyw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/anella-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 434,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73327, 'longitude': -73.95786},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '222 Franklin St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['222 Franklin St', 'Brooklyn, NY 11222']},
#   'phone': '+17183898100',
#   'display_phone': '(718) 389-8100',
#   'distance': 4354.831102659747},
#  {'id': 'g-Wk89t79HQqhXM06sv9Ug',
#   'alias': 'la-nova-brick-oven-pizza-brooklyn',
#   'name': 'La Nova Brick Oven Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iDgLqhYR01igzlL6qulO8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-nova-brick-oven-pizza-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 17,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.68476, 'longitude': -73.914},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1636 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11207',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1636 Broadway', 'Brooklyn, NY 11207']},
#   'phone': '+13474258391',
#   'display_phone': '(347) 425-8391',
#   'distance': 7148.712801733449},
#  {'id': 'xmwzq6ix7_5fgPs2BaEjBg',
#   'alias': 'zio-pepe-s-pizzeria-queens',
#   'name': 'Zio Pepe’s Pizzeria',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LXrRoZUpnuE8QB905e0yvg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zio-pepe-s-pizzeria-queens?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 17,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.77621, 'longitude': -73.91521},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '26-19 23rd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Queens',
#    'zip_code': '11105',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['26-19 23rd Ave', 'Queens, NY 11105']},
#   'phone': '+17184339858',
#   'display_phone': '(718) 433-9858',
#   'distance': 10310.571725376916},
#  {'id': 'evBdhciqQRomxzFsGmeACg',
#   'alias': 'romeos-pizzeria-ozone-park-2',
#   'name': "Romeo's Pizzeria",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/67ODAjhdE6QueqxgiMWPzw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/romeos-pizzeria-ozone-park-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 126,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.67389, 'longitude': -73.84348},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '134-24 Crossbay Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Ozone Park',
#    'zip_code': '11417',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['134-24 Crossbay Blvd', 'Ozone Park, NY 11417']},
#   'phone': '+17188453300',
#   'display_phone': '(718) 845-3300',
#   'distance': 13187.688421772773},
#  {'id': 'AIMdnPeYEJocydccQZtlfA',
#   'alias': 'sabrinas-pizzeria-and-restaurant-brooklyn',
#   'name': "Sabrina's Pizzeria & Restaurant",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9EKtj1sFq2ufpGexieOMBw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sabrinas-pizzeria-and-restaurant-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 33,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.708374, 'longitude': -73.958327},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '294 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['294 Broadway', 'Brooklyn, NY 11211']},
#   'phone': '+17183877743',
#   'display_phone': '(718) 387-7743',
#   'distance': 3050.6661762700996},
#  {'id': 'JSMbeYk4z17jt80DuHaYRQ',
#   'alias': '99-cent-fresh-pizza-new-york',
#   'name': '99 Cent Fresh Pizza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LaRGylpC-_F8quHkweq1Qg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/99-cent-fresh-pizza-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 273,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7517, 'longitude': -73.97432},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '151 E 43rd St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['151 E 43rd St', 'New York, NY 10017']},
#   'phone': '+12129220257',
#   'display_phone': '(212) 922-0257',
#   'distance': 5413.055965134025},
#  {'id': 'mXLrVoEi80WZaZ3agBP5Jw',
#   'alias': 'bijans-brooklyn-2',
#   'name': "Bijan's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VJmLtQJ2tXq9qjlhGGMVxg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bijans-brooklyn-2?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 635,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.68803, 'longitude': -73.98671},
#   'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '81 Hoyt St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['81 Hoyt St', 'Brooklyn, NY 11211']},
#   'phone': '+17188555574',
#   'display_phone': '(718) 855-5574',
#   'distance': 2042.3931483811346},
#  {'id': 'c4PIUs7uwg9lA4ObzJ4V5Q',
#   'alias': 'barosa-rego-park',
#   'name': 'Barosa',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A6sRMh4z-E5fouDZUkKbVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/barosa-rego-park?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 396,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.726197, 'longitude': -73.869795},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '62-29 Woodhaven Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Rego Park',
#    'zip_code': '11374',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['62-29 Woodhaven Blvd', 'Rego Park, NY 11374']},
#   'phone': '+17184241455',
#   'display_phone': '(718) 424-1455',
#   'distance': 10743.51518196361},
#  {'id': 'EZCOwqdPJnTBiDLuZ3IjNQ',
#   'alias': 'doughnuttery-new-york-5',
#   'name': 'Doughnuttery',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/s17q7k2tt5RLUKE8Zo0rHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/doughnuttery-new-york-5?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 62,
#   'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#    {'alias': 'food_court', 'title': 'Food Court'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.764217639935,
#    'longitude': -73.97427336103556},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': 'One W 58th St',
#    'address2': '',
#    'address3': 'Plaza Hotel',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['One W 58th St', 'Plaza Hotel', 'New York, NY 10019']},
#   'phone': '+12126334359',
#   'display_phone': '(212) 633-4359',
#   'distance': 6749.407176068485},
#  {'id': 'TsYrzVVtkKO4Asrk_L9stw',
#   'alias': 'parm-new-york-new-york',
#   'name': 'Parm - New York',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/w5V7EBk7gA-0EpYJEZUPSQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/parm-new-york-new-york?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 653,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.7764333, 'longitude': -73.9794019},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '235 Columbus Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10023',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['235 Columbus Ave', 'New York, NY 10023']},
#   'phone': '+12127764921',
#   'display_phone': '(212) 776-4921',
#   'distance': 7995.288414327454},
#  {'id': 'VBuF671en_sI7wV5aYkrpg',
#   'alias': 'enzos-pizzeria-ozone-park',
#   'name': "Enzo's Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fQsOuvvOKofW2mQc3QWfTg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/enzos-pizzeria-ozone-park?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 100,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.6842863, 'longitude': -73.8594333},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '8102 Rockaway Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Ozone Park',
#    'zip_code': '11416',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8102 Rockaway Blvd', 'Ozone Park, NY 11416']},
#   'phone': '+17182960880',
#   'display_phone': '(718) 296-0880',
#   'distance': 11619.704421961838},
#  {'id': '_SX-H3lkHpWGDVBdD3XiQw',
#   'alias': 'villa-meci-pizzeria-glen-cove',
#   'name': 'Villa Meci Pizzeria',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WQnxP3DLJsRGUv-VHB4GEg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/villa-meci-pizzeria-glen-cove?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 80,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.8481627306549, 'longitude': -73.635030192143},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '214 Glen Cove Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Glen Cove',
#    'zip_code': '11542',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['214 Glen Cove Ave', 'Glen Cove, NY 11542']},
#   'phone': '+15168014400',
#   'display_phone': '(516) 801-4400',
#   'distance': 34160.93185524884},
#  {'id': '3JyRCbl4KeK2sY48xu0m-w',
#   'alias': 'emilios-pizza-bronx',
#   'name': "Emilio's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/excrnQp6KseNmrorHvs1OQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/emilios-pizza-bronx?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 28,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.867915, 'longitude': -73.900536},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '80 W Kingsbridge Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10468',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['80 W Kingsbridge Rd', 'Bronx, NY 10468']},
#   'phone': '+17185633665',
#   'display_phone': '(718) 563-3665',
#   'distance': 19716.120042250703},
#  {'id': 'Z3yjBSmuoQbz6olnO_S1tQ',
#   'alias': 'cheeseboat-brooklyn',
#   'name': 'Cheeseboat',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EXqqOfz9T_b-J9WPL1TC4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cheeseboat-brooklyn?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 466,
#   'categories': [{'alias': 'georgian', 'title': 'Georgian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71994, 'longitude': -73.95791},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '80 Berry St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['80 Berry St', 'Brooklyn, NY 11249']},
#   'phone': '+19292958401',
#   'display_phone': '(929) 295-8401',
#   'distance': 3470.0255211355047},
#  {'id': 'g5RqTm1v8Stsm3MXL19Adw',
#   'alias': 'romans-brooklyn-3',
#   'name': "Roman's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lHm_c2gqNTvU9RtYHanpJw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/romans-brooklyn-3?adjust_creative=f9pnHGp7FmBVsuU2r4z_ag&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=f9pnHGp7FmBVsuU2r4z_ag',
#   'review_count': 254,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.689671, 'longitude': -73.96953},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '243 DeKalb Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['243 DeKalb Ave', 'Brooklyn, NY 11205']},
#   'phone': '+17186225300',
#   'display_phone': '(718) 622-5300',
#   'distance': 2729.113299667744}]

# %% [markdown]
# This code may take up to a few minutes to run.
#
# If you get an error trying to get the response body in JSON format, try adding `time.sleep(1)` right after the `requests.get` line, so your code will sleep for 1 second between each API call.

# %% [markdown]
# ## 3. Perform Exploratory Analysis
#
# Take the businesses from the previous question and do an initial exploratory analysis. We have provided some plots for you to interpret:

# %%
# Run this cell without changes
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(16, 5))

# Plot distribution of number of reviews
all_review_counts = [x["review_count"] for x in full_dataset]
ax1.hist(all_review_counts)
ax1.set_title("Review Count Distribution")
ax1.set_xlabel("Number of Reviews")
ax1.set_ylabel("Number of Businesses")

# Plot rating distribution
all_ratings = [x["rating"] for x in full_dataset]
rating_counter = Counter(all_ratings)
rating_keys = sorted(rating_counter.keys())
ax2.bar(rating_keys, [rating_counter[key] for key in rating_keys])
ax2.set_title("Rating Distribution")
ax2.set_xlabel("Rating")
ax2.set_ylabel("Number of Businesses")

# Plot price distribution
all_prices = [x["price"].replace("$", r"\$") for x in full_dataset]
price_counter = Counter(all_prices)
price_keys = sorted(price_counter.keys())
ax3.bar(price_keys, [price_counter[key] for key in price_keys])
ax3.set_title("Price Distribution")
ax3.set_xlabel("Price Category")
ax3.set_ylabel("Number of Businesses");

# %% [markdown]
# Describe the distributions displayed above and interpret them in the context of your query. (Your answer may differ from the solution branch depending on your query.)

# %%
# Replace None with appropriate text
"""
For the majority, pizza is tasty and cheap!  It appears that the majority of businesses had <1000 reviews, 
as the review count dist is heavily skewed left.  I would remove the outliers and increase the bin size to get a 
more accurate representation.  The rating distribution seems close to a normal distribution, which we could could 
validate by juxtaposing the median and mean.  It appears the average queried business has ~4 stars on yelp.  Finally, 
the price distribution shows that the large majority of pizza ristorantes are "$$" or less. 
"""
# Out:
# '\nFor the majority, pizza is tasty and cheap!  It appears that the majority of businesses had <1000 reviews, \nas the review count dist is heavily skewed left.  I would remove the outliers and increase the bin size to get a \nmore accurate representation.  The rating distribution seems close to a normal distribution, which we could could \nvalidate by juxtaposing the median and mean.  It appears the average queried business has ~4 stars on yelp.  Finally, \nthe price distribution shows that the large majority of pizza ristorantes are "$$" or less. \n'

# %% [markdown]
# In the cell below, we also plot the rating distributions by price. In this setup, a price of one dollar sign is "lower price" and everything else is "higher price".

# %%
# Run this cell without changes

higher_price = []
lower_price = []
for row in full_dataset:
    if row["price"] == "$":
        lower_price.append(row["rating"])
    else:
        higher_price.append(row["rating"])
        
fig, ax = plt.subplots()

ax.hist([higher_price, lower_price], label=["higher price", "lower price"], density=True)

ax.legend();

# %% [markdown]
# Is a higher price associated with a higher rating? (No need for any additional math/statistics, just interpret what you see in the plot.)

# %%
# Replace None with appropriate text
"""
I disagree with the way the data is visualized in the above figure.  $ and $$ should be lower, and $$$+ should be 
higher.  it does appear that ratings correlate with price, but there is no way to say for certain without measures
of statistical sig.
"""

higher_price = []
lower_price = []
for row in full_dataset:
    if row["price"] in ["$", "$$"]:
        lower_price.append(row["rating"])
    else:
        higher_price.append(row["rating"])
        
fig, ax = plt.subplots()

ax.hist([higher_price, lower_price], label=["higher price", "lower price"], density=True)

ax.legend();

# %% [markdown]
# Finally, let's look at ratings vs. review counts:

# %%
# Run this cell without changes
fig, ax = plt.subplots(figsize=(16,5))

ax.scatter(all_review_counts, all_ratings, alpha=0.2)
ax.set_xlabel("Number of Reviews")
ax.set_ylabel("Rating")
# "zoom in" to a subset of review counts
ax.set_xlim(left=0, right=1000);

# %% [markdown]
# Is a higher number of reviews associated with a higher rating?

# %%
# Replace None with appropriate text
"""
it does not appear so, no. 
"""

# %% [markdown]
# ## 4. Create a Folium Map
#
# Make a map using Folium of the businesses you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.
#
# You can center the map around the latitude and longitude of the first item in `full_dataset`.

# %%
from statistics import mean

# Set up center latitude and longitude
center_lat = mean([b["latitude"] for b in full_dataset])
center_long = mean([b["longitude"] for b in full_dataset])

# Initialize map with center lat and long
yelp_map = folium.Map((center_lat, center_long), zoom_start=13)

# Adjust this limit to see more or fewer businesses
limit=100

for b in full_dataset[:limit]:
    # Extract information about business
    lat = b["latitude"]
    long = b["longitude"]
    name = b["name"]
    rating = b["rating"]
    price = b["price"]
    details = f"{name}\nPrice: {price} Rating:{rating}"
    
    # Create popup with relevant details
    popup = folium.Popup(details, parse_html=True)
    
    # Create marker with relevant lat/long and popup
    marker = folium.Marker(location=[lat, long], popup=popup)
    
    marker.add_to(yelp_map)
    
yelp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61635033da9619ba56b39b1c2d852ae9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61635033da9619ba56b39b1c2d852ae9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_61635033da9619ba56b39b1c2d852ae9 = L.map(
#                 &quot;map_61635033da9619ba56b39b1c2d852ae9&quot;,
#                 {
#                     center: [40.71711975709753, -74.0020236318134],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_524b567754aae9d259b6a6af65e827e1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_61635033da9619ba56b39b1c2d852ae9);
#
#
#             var marker_9116e248b8dcf0d62e2ddca1d1a3fe2a = L.marker(
#                 [40.72308755605564, -73.99453001177575],
#                 {}
#             ).addTo(map_61635033da9619ba56b39b1c2d852ae9);
#
#
#         var popup_a7b7d9500e5d4cfaa3a84298ef8b712c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8e32440f8d22d25d85a0ea404de2f895 = $(`&lt;div id=&quot;html_8e32440f8d22d25d85a0ea404de2f895&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Prince Street Pizza Price: $ Rating:4.5&lt;/div&gt;`)[0];
#             popup_a7b7d9500e5d4cfaa3a84298ef8b712c.setContent(html_8e32440f8d22d25d85a0ea404de2f895);
#
#
#         marker_9116e248b8dcf0d62e2ddca1d1a3fe2a.bindPopup(popup_a7b7d9500e5d4cfaa3a84298ef8b712c)
#         ;
#
#
#
#
#             var marker_5a931eeb9ab98fb4f9f92dae0d7eb6c1 = L.marker(
#                 [40.70274718768062, -73.99343490196397],
#                 {}
#             ).addTo(map_61635033da9619ba56b39b1c2d852ae9);
#
#
#         var popup_9611354c30a8172fab109887836c04e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cb861273e73ae7ea3317f39c0a8e360a = $(`&lt;div id=&quot;html_cb861273e73ae7ea3317f39c0a8e360a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Juliana&amp;#39;s Price: $$ Rating:4.5&lt;/div&gt;`)[0];
#             popup_9611354c30a8172fab109887836c04e6.setContent(html_cb861273e73ae7ea3317f39c0a8e360a);
#
#
#         marker_5a931eeb9ab98fb4f9f92dae0d7eb6c1.bindPopup(popup_9611354c30a8172fab109887836c04e6)
#         ;
#
#
#
#
#             var marker_03da81f56538f70cfc915fa692c18e8f = L.marker(
#                 [40.7215934960083, -73.9955956044561],
#                 {}
#             ).addTo(map_61635033da9619ba56b39b1c2d852ae9);
#
#
#         var popup_a76e69459dbeb8694afb5d8ff26b9214 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4797070f32c002390990d6ffafbaa836 = $(`&lt;div id=&quot;html_4797070f32c002390990d6ffafbaa836&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lombardi&amp;#39;s Pizza Price: $$ Rating:4.0&lt;/div&gt;`)[0];
#             popup_a76e69459dbeb8694afb5d8ff26b9214.setContent(html_4797070f32c002390990d6ffafbaa836);
#
#
#         marker_03da81f56538f70cfc915fa692c18e8f.bindPopup(popup_a76e69459dbeb8694afb5d8ff26b9214)
#         ;
#
#
#
#
#             var marker_02ceb8c07957d5e3c43401c10d8fad31 = L.marker(
#                 [40.71162, -73.95783],
#                 {}
#             ).addTo(map_61635033da9619ba56b39b1c2d852ae9);
#
#
#         var popup_5318822bdf1b81922434de10f23af3db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_25fc08f7ff4d749b7b4d228429389ac1 = $(`&lt;div id=&quot;html_25fc08f7ff4d749b7b4d228429389ac1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;L&amp;#39;industrie Pizzeria Price: $ Rating:4.5&lt;/div&gt;`)[0];
#             popup_5318822bdf1b81922434de10f23af3db.setContent(html_25fc08f7ff4d749b7b4d228429389ac1);
#
#
#         marker_02ceb8c07957d5e3c43401c10d8fad31.bindPopup(popup_5318822bdf1b81922434de10f23af3db)
#         ;
#
#
#
#
#             var marker_8c4dc73e6add8ed688d20ffe41672e05 = L.marker(
#                 [40.722766, -73.996233],
#                 {}
#             ).addTo(map_61635033da9619ba56b39b1c2d852ae9);
#
#
#         var popup_5ee57e31647ab71e2af42e2db1f63665 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_38eed3c270e594eb9fa90fc830aadcbc = $(`&lt;div id=&quot;html_38eed3c270e594eb9fa90fc830aadcbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rubirosa Price: $$ Rating:4.5&lt;/div&gt;`)[0];
#             popup_5ee57e31647ab71e2af42e2db1f63665.setContent(html_38eed3c270e594eb9fa90fc830aadcbc);
#
#
#         marker_8c4dc73e6add8ed688d20ffe41672e05.bindPopup(popup_5ee57e31647ab71e2af42e2db1f63665)
#         ;
#
#
#
#
#             var marker_f1b2b8b1ea487b4e98214fbde1df0dc8 = L.marker(
#                 [40.681840746711224, -74.0003327],
#                 {}
#             ).addTo(map_61635033da9619ba56b39b1c2d852ae9);
#
#
#         var popup_9347

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you've made multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice interactive map to display the results using Folium! Well done!
